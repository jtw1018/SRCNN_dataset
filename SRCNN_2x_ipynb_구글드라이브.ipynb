# %% [markdown]
# <a href="https://colab.research.google.com/github/jtw1018/SRCNN_dataset/blob/main/SRCNN_ipynb(20201013).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Super-Resolution Convolutional Neural Network
# > In this project, it will show CNN model that can enhance the resolution of image using Convolutional Neural Network. The topic is from the paper "Image Super-Resolution Using Deep Convolutional Networks", presented in ECCV 2014.
#
# - toc: true
# - badges: true
# - comments: true
# - author: Chanseok Kang
# - categories: [Python, Deep_Learning, Vision, Tensorflow-Keras]
# - image: images/srcnn_result.png

# %% [markdown]
# [Image Super-Resolution Using Deep Convolutional Network](https://arxiv.org/abs/1501.00092) (Dong et al. 2014) introduced the Super-Resolution Convolutional Neural Network (SR-CNN for short) that can enhance the resolution of original image. SR-CNN is deep convolutional neural network that learns end-to-end mapping of low resolution to high resolution image. In this post, we will dig into the basic principles of SR-CNN, and implement it.

# %%
# !nvidia-smi ## check GPU allocation
# Out:
# Sun Dec  4 15:34:15 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    27W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 구글드라이브 마운트

# %%
## mount google drive

from google.colab import drive

drive.mount('/content/drive')
# %cd /content/drive/MyDrive/VisionAI/SRCNN_2x
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/VisionAI/SRCNN_2x

# %% [markdown]
# ## Required Packages

# %%
import sys, os
import math
import tensorflow as tf
import numpy as np
import pandas as pd
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# ## Version check

# %%
print('Python: {}'.format(sys.version))
print('Numpy: {}'.format(np.__version__))
print('Pandas: {}'.format(pd.__version__))
print('OpenCV: {}'.format(cv2.__version__))
print('Tensorflow: {}'.format(tf.__version__))
print('Matplotlib: {}'.format(mpl.__version__))
print('Scikit-Image: {}'.format(skimage.__version__))
# Out:
# Python: 3.8.15 (default, Oct 12 2022, 19:14:39)
# [GCC 7.5.0]
# Numpy: 1.21.6
# Pandas: 1.3.5
# OpenCV: 4.6.0
# Tensorflow: 2.9.2
# Matplotlib: 3.2.2
# Scikit-Image: 0.18.3

# %% [markdown]
# ## Metric Functions
# 사실 우리가 raw 이미지를 보았을 때 이 이미지가 고해상도 이미지인지 아닌지 확인할 수 없습니다.
# 이미지 품질을 측정하는 몇 가지 메트릭
#
# - [Peak Signal to Noise Ratio](https://en.wikipedia.org/wiki/Peak_signal-to-noise_ratio) (PSNR)
# - Mean Squared Error (MSE)
# - [Structural Similarity](https://en.wikipedia.org/wiki/Structural_similarity) (SSIM)

# %% [markdown]
# ### Peak Signal-to-Noise Ratio (PSNR)

# %%
def psnr(target, ref):
    # Assume target is RGB/BGR image
    target_data = target.astype(np.float32)
    ref_data = ref.astype(np.float32)
    
    diff = ref_data - target_data
    diff = diff.flatten('C')
    
    rmse = np.sqrt(np.mean(diff ** 2.))
    
    return 20 * np.log10(255. / rmse)

# %% [markdown]
# ### Mean Squared Error (MSE)

# %%
def mse(target, ref):
    target_data = target.astype(np.float32)
    ref_data = ref.astype(np.float32)
    err = np.sum((target_data - ref_data) ** 2)
    
    err /= np.float(target_data.shape[0] * target_data.shape[1])
    return err

# %% [markdown]
# ### 구조적 유사성
# 실제로 이 메트릭은 이미 skimage에 구현되어 있습니다.

# %%
from skimage.metrics import structural_similarity as ssim

# %% [markdown]
# 이미지 품질을 측정하기 위한 메트릭을 정의한 후에는 전체 메트릭을 하나의 메트릭으로 결합해야 합니다.

# %%
def compare_images(target, ref):
    scores = []
    scores.append(psnr(target, ref))
    scores.append(mse(target, ref))
    scores.append(ssim(target, ref, multichannel=True))
    return scores

# %% [markdown]
# ## Prepare distorted images via resizing
# 원시 데이터에서 어떻게 왜곡된 이미지를 만들 수 있습니까? 간단합니다. 원본 이미지를 축소한 후 이전 너비 높이로 다시 크기를 조정하면 크기 조정 중에 픽셀 정보가 손실될 수 있으므로 해상도가 낮아집니다.

# %%
def prepare_images(path, factor):
    # Loop through the files in the directory
    for file in os.listdir(path):
        image = cv2.imread(path + '/' + file)
        
        # Find old and new image dimensions
        h, w, c = image.shape
        new_height = int(h / factor)
        new_width = int(w / factor)
        
        # Resize down the image
        image = cv2.resize(image, (new_width, new_height), interpolation=cv2.INTER_LINEAR)
        
        # Resize up the image
        image = cv2.resize(image, (w, h), interpolation=cv2.INTER_LINEAR)
        
        # Save the image
        try:
            os.listdir(path + '/../../resized')
        except:
            os.mkdir(path + '/../../resized')
            
        cv2.imwrite(path + '/../../resized/{}'.format(file), image)

# %%
prepare_images('./Test/Set5', 2)

# %% [markdown]
# Let's see it works.

# %%
from PIL import Image
fig, ax = plt.subplots(1, 2, figsize=(15, 10))
ax[0].imshow(Image.open('./Test/Set5/butterfly_GT.bmp'))
ax[0].title.set_text('Original Image')
ax[1].imshow(Image.open('./resized/butterfly_GT.bmp'))
ax[1].title.set_text('Resized Image')
plt.show()

# %% [markdown]
# 왼쪽 이미지에 비해 오른쪽 이미지가 약간 흐릿한 것을 볼 수 있습니다. 확인할 수 없으면 이전에 정의한 메트릭 함수를 사용하십시오.

# %%
target = cv2.imread('./Test/Set5/butterfly_GT.bmp')
ref = cv2.imread('./resized/butterfly_GT.bmp')

metrics = compare_images(target, ref)
print("PSNR: {}".format(metrics[0]))
print("MSE: {}".format(metrics[1]))
print("SSIM: {}".format(metrics[2]))
# Out:
# PSNR: 24.78207598456035
# MSE: 648.62548828125
# SSIM: 0.8791344763843051
# <ipython-input-5-dffab844877c>:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   err /= np.float(target_data.shape[0] * target_data.shape[1])

# %% [markdown]
# ## Data Augmentation

# %% [markdown]
# 실제로 임의 자르기와 같은 데이터 증대를 위한 여러 가지 변환이 있습니다. [누군가](https://github.com/MarkPrecursor/SRCNN-keras/blob/master/prepare_data.py)는 스크립트를 통해 h5 형식의 데이터 세트를 만들었으므로 거기에서 차용합니다.

# %%
# ref - https://github.com/MarkPrecursor/SRCNN-keras/blob/master/prepare_data.py
# Build train dataset
import h5py

names = sorted(os.listdir('./Train'))

data = []
label = []

for name in names:
    fpath = './Train/' + name
    hr_img = cv2.imread(fpath, cv2.IMREAD_COLOR)
    hr_img = cv2.cvtColor(hr_img, cv2.COLOR_BGR2YCrCb)
    hr_img = hr_img[:, :, 0]
    shape = hr_img.shape
    
    # resize operation to produce training data and labels
    lr_img = cv2.resize(hr_img, (int(shape[1] / 2), int(shape[0] / 2)))
    lr_img = cv2.resize(lr_img, (shape[1], shape[0]))
    
    width_range = int((shape[0] - 16 * 2) / 16)
    height_range = int((shape[1] - 16 * 2) / 16)
    
    for k in range(width_range):
        for j in range(height_range):
            x = k * 16
            y = j * 16
            
            hr_patch = hr_img[x: x + 32, y: y + 32]
            lr_patch = lr_img[x: x + 32, y: y + 32]
            
            hr_patch = hr_patch.astype(np.float32) / 255.
            lr_patch = lr_patch.astype(np.float32) / 255.
            
            hr = np.zeros((1, 20, 20), dtype=np.double)
            lr = np.zeros((1, 32, 32), dtype=np.double)
            
            hr[0, :, :] = hr_patch[6:-6, 6: -6]
            lr[0, :, :] = lr_patch
            
            label.append(hr)
            data.append(lr)

data = np.array(data, dtype=np.float32)
label = np.array(label, dtype=np.float32)

# %%
with h5py.File('train.h5', 'w') as h:
    h.create_dataset('data', data=data, shape=data.shape)
    h.create_dataset('label', data=label, shape=label.shape)

# %%
# ref - https://github.com/MarkPrecursor/SRCNN-keras/blob/master/prepare_data.py
# Build test dataset

names = sorted(os.listdir('./Test/Set5'))
nums = len(names)

data_test = np.zeros((nums * 30, 1, 32, 32), dtype=np.double)
label_test = np.zeros((nums * 30, 1, 20, 20), dtype=np.double)

for i, name in enumerate(names):
    fpath = './Test/Set5/' + name
    hr_img = cv2.imread(fpath, cv2.IMREAD_COLOR)
    hr_img = cv2.cvtColor(hr_img, cv2.COLOR_BGR2YCrCb)
    hr_img = hr_img[:, :, 0]
    shape = hr_img.shape
    
    # resize operation to produce training data and labels
    lr_img = cv2.resize(hr_img, (int(shape[1] / 2), int(shape[0] / 2)))
    lr_img = cv2.resize(lr_img, (shape[1], shape[0]))
    
    # Produce random crop
    x = np.random.randint(0, min(shape[0], shape[1]) - 32, 30)
    y = np.random.randint(0, min(shape[0], shape[1]) - 32, 30)
    
    for j in range(30):
        lr_patch = lr_img[x[j]:x[j] + 32, y[j]:y[j] + 32]
        hr_patch = hr_img[x[j]:x[j] + 32, y[j]:y[j] + 32]
        
        lr_patch = lr_patch.astype(np.float32) / 255.
        hr_patch = hr_patch.astype(np.float32) / 255.
        
        data_test[i * 30 + j, 0, :, :] = lr_patch
        label_test[i * 30 + j, 0, :, :] = hr_patch[6: -6, 6: -6]

# %%
with h5py.File('test.h5', 'w') as h:
    h.create_dataset('data', data=data_test, shape=data_test.shape)
    h.create_dataset('label', data=label_test, shape=label_test.shape)

# %% [markdown]
# ## Build SR-CNN Model
# 데이터 세트를 h5 형식으로 준비했습니다. 또한 tensorflow를 사용하여 SR-CNN 모델을 구축해야 합니다. Keras 프레임워크가 tensorflow v2.x에 통합되어 있다는 것을 이미 알고 있습니다. 따라서 tensorflow-keras 모델로 구현할 수 있습니다. 이 경우 순차 모델로 빌드합니다.

# %%
# Define the SR-CNN model
def model():
    SRCNN = tf.keras.Sequential(name='SRCNN')
    SRCNN.add(tf.keras.layers.Conv2D(filters=128, kernel_size=(9, 9), 
                                     padding='VALID',
                                     use_bias=True,
                                     input_shape=(None, None, 1),
                                     kernel_initializer='glorot_uniform',
                                     activation='relu'))
    SRCNN.add(tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3),
                                     padding='SAME',
                                     use_bias=True,
                                     kernel_initializer='glorot_uniform',
                                     activation='relu'))
    SRCNN.add(tf.keras.layers.Conv2D(filters=1, kernel_size=(5, 5),
                                     padding='VALID',
                                     use_bias=True,
                                     kernel_initializer='glorot_uniform',
                                     activation='linear'))
    # Optimizer
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0003)
    
    # Compile model
    SRCNN.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_squared_error'])
    
    return SRCNN

# %% [markdown]
# ## Train the model
# 이제 모델을 학습시킬 차례입니다. 우리 모델은 어떻게 생겼습니까?

# %%
srcnn_model = model()
srcnn_model.summary()
# Out:
# Model: "SRCNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, None, None, 128)   10496
#
#  conv2d_1 (Conv2D)           (None, None, None, 64)    73792
#
#  conv2d_2 (Conv2D)           (None, None, None, 1)     1601
#
# =================================================================
# Total params: 85,889
# Trainable params: 85,889
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 미리 빌드된 h5 파일에서 데이터 세트를 로드합니다. 체크포인트를 정의하는데 도움이 될 것입니다.

# %%
with h5py.File('./train.h5', 'r') as h:
    data = np.array(h.get('data'))
    label = np.array(h.get('label'))
    X_train = np.transpose(data, (0, 2, 3, 1))
    y_train = np.transpose(label, (0, 2, 3, 1))
    
with h5py.File('./test.h5', 'r') as h:
    data = np.array(h.get('data'))
    label = np.array(h.get('label'))
    X_test = np.transpose(data, (0, 2, 3, 1))
    y_test = np.transpose(label, (0, 2, 3, 1))
    
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((14901, 32, 32, 1), (14901, 20, 20, 1), (150, 32, 32, 1), (150, 20, 20, 1))

# %%
checkpoint_path = './srcnn/cp-{epoch:04d}.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_dir, save_best_only=True,
                                                 save_weights_only=True, verbose=0)

# %%
srcnn_model.fit(X_train, y_train, batch_size=64, validation_data=(X_test, y_test), 
                callbacks=[checkpoint], shuffle=True, epochs=200, verbose=True)
# Out:
# Epoch 1/200
# 233/233 [==============================] - 11s 11ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 9.7774e-04 - val_mean_squared_error: 9.7774e-04
# Epoch 2/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 8.5879e-04 - val_mean_squared_error: 8.5879e-04
# Epoch 3/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.2161e-04 - val_mean_squared_error: 7.2161e-04
# Epoch 4/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 7.2541e-04 - val_mean_squared_error: 7.2541e-04
# Epoch 5/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.6749e-04 - val_mean_squared_error: 6.6749e-04
# Epoch 6/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.4686e-04 - val_mean_squared_error: 6.4686e-04
# Epoch 7/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.2593e-04 - val_mean_squared_error: 6.2593e-04
# Epoch 8/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.9946e-04 - val_mean_squared_error: 5.9946e-04
# Epoch 9/200
# 233/233 [==============================] - 2s 7ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.0298e-04 - val_mean_squared_error: 6.0298e-04
# Epoch 10/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.8657e-04 - val_mean_squared_error: 5.8657e-04
# Epoch 11/200
# 233/233 [==============================] - 2s 7ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.9455e-04 - val_mean_squared_error: 5.9455e-04
# Epoch 12/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.6414e-04 - val_mean_squared_error: 5.6414e-04
# Epoch 13/200
# 233/233 [==============================] - 2s 7ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.8312e-04 - val_mean_squared_error: 5.8312e-04
# Epoch 14/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.5552e-04 - val_mean_squared_error: 5.5552e-04
# Epoch 15/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.5293e-04 - val_mean_squared_error: 5.5293e-04
# Epoch 16/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.5857e-04 - val_mean_squared_error: 5.5857e-04
# Epoch 17/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.4308e-04 - val_mean_squared_error: 5.4308e-04
# Epoch 18/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.8350e-04 - val_mean_squared_error: 5.8350e-04
# Epoch 19/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.4138e-04 - val_mean_squared_error: 5.4138e-04
# Epoch 20/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.2577e-04 - val_mean_squared_error: 5.2577e-04
# Epoch 21/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.3017e-04 - val_mean_squared_error: 5.3017e-04
# Epoch 22/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.1477e-04 - val_mean_squared_error: 5.1477e-04
# Epoch 23/200
# 233/233 [==============================] - 2s 7ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.2609e-04 - val_mean_squared_error: 5.2609e-04
# Epoch 24/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 7.0730e-04 - val_mean_squared_error: 7.0730e-04
# Epoch 25/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.0876e-04 - val_mean_squared_error: 5.0876e-04
# Epoch 26/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.2025e-04 - val_mean_squared_error: 5.2025e-04
# Epoch 27/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.3533e-04 - val_mean_squared_error: 5.3533e-04
# Epoch 28/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.0873e-04 - val_mean_squared_error: 5.0873e-04
# Epoch 29/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.0579e-04 - val_mean_squared_error: 5.0579e-04
# Epoch 30/200
# 233/233 [==============================] - 2s 7ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.1265e-04 - val_mean_squared_error: 5.1265e-04
# Epoch 31/200
# 233/233 [==============================] - 2s 7ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.1604e-04 - val_mean_squared_error: 5.1604e-04
# Epoch 32/200
# 233/233 [==============================] - 2s 7ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 5.3220e-04 - val_mean_squared_error: 5.3220e-04
# Epoch 33/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.9815e-04 - val_mean_squared_error: 4.9815e-04
# Epoch 34/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.1745e-04 - val_mean_squared_error: 5.1745e-04
# Epoch 35/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.9904e-04 - val_mean_squared_error: 4.9904e-04
# Epoch 36/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.9325e-04 - val_mean_squared_error: 4.9325e-04
# Epoch 37/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 6.4635e-04 - val_mean_squared_error: 6.4635e-04
# Epoch 38/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.1281e-04 - val_mean_squared_error: 5.1281e-04
# Epoch 39/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.1664e-04 - val_mean_squared_error: 5.1664e-04
# Epoch 40/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.0393e-04 - val_mean_squared_error: 5.0393e-04
# Epoch 41/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.0697e-04 - val_mean_squared_error: 5.0697e-04
# Epoch 42/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.9679e-04 - val_mean_squared_error: 4.9679e-04
# Epoch 43/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.7775e-04 - val_mean_squared_error: 4.7775e-04
# Epoch 44/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.8972e-04 - val_mean_squared_error: 4.8972e-04
# Epoch 45/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.8665e-04 - val_mean_squared_error: 4.8665e-04
# Epoch 46/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.9436e-04 - val_mean_squared_error: 4.9436e-04
# Epoch 47/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.8577e-04 - val_mean_squared_error: 4.8577e-04
# Epoch 48/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.9124e-04 - val_mean_squared_error: 4.9124e-04
# Epoch 49/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.9237e-04 - val_mean_squared_error: 4.9237e-04
# Epoch 50/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.2035e-04 - val_mean_squared_error: 5.2035e-04
# Epoch 51/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 5.4135e-04 - val_mean_squared_error: 5.4135e-04
# Epoch 52/200
# 233/233 [==============================] - 2s 8ms/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 4.9848e-04 - val_mean_squared_error: 4.9848e-04
# Epoch 53/200
# 233/233 [==============================] - 2s 8ms/step - loss: 9.9728e-04 - mean_squared_error: 9.9728e-04 - val_loss: 4.7470e-04 - val_mean_squared_error: 4.7470e-04
# Epoch 54/200
# 233/233 [==============================] - 2s 8ms/step - loss: 9.9299e-04 - mean_squared_error: 9.9299e-04 - val_loss: 5.1155e-04 - val_mean_squared_error: 5.1155e-04
# Epoch 55/200
# 233/233 [==============================] - 2s 7ms/step - loss: 9.9252e-04 - mean_squared_error: 9.9252e-04 - val_loss: 4.8187e-04 - val_mean_squared_error: 4.8187e-04
# Epoch 56/200
# 233/233 [==============================] - 2s 8ms/step - loss: 9.9416e-04 - mean_squared_error: 9.9416e-04 - val_loss: 4.9348e-04 - val_mean_squared_error: 4.9348e-04
# Epoch 57/200
# 233/233 [==============================] - 2s 8ms/step - loss: 9.9306e-04 - mean_squared_error: 9.9306e-04 - val_loss: 4.7989e-04 - val_mean_squared_error: 4.7989e-04
# Epoch 58/200
# 233/233 [==============================] - 2s 8ms/step - loss: 9.8837e-04 - mean_squared_error: 9.8836e-04 - val_loss: 4.8675e-04 - val_mean_squared_error: 4.8675e-04
# Epoch 59/200
# 233/233 [==============================] - 2s 8ms/step - loss: 9.8944e-04 - mean_squared_error: 9.8944e-04 - val_loss: 4.7969e-04 - val_mean_squared_error: 4.7969e-04
# Epoch 60/200
# 233/233 [==============================] - 2s 8ms/step - loss: 9.8446e-04 - mean_squared_error: 9.8446e-04 - val_loss: 4.9247e-04 - val_mean_squared_error: 4.9247e-04
# Epoch 61/200
# 233/233 [==============================] - 2s 8ms/step - loss: 9
200
# 233/233 [==============================] - 2s 8ms/step - loss: 8.8021e-04 - mean_squared_error: 8.8021e-04 - val_loss: 4.7204e-04 - val_mean_squared_error: 4.7204e-04
# Epoch 193/200
# 233/233 [==============================] - 2s 8ms/step - loss: 8.8077e-04 - mean_squared_error: 8.8077e-04 - val_loss: 4.8031e-04 - val_mean_squared_error: 4.8031e-04
# Epoch 194/200
# 233/233 [==============================] - 2s 8ms/step - loss: 8.7911e-04 - mean_squared_error: 8.7911e-04 - val_loss: 4.8601e-04 - val_mean_squared_error: 4.8601e-04
# Epoch 195/200
# 233/233 [==============================] - 2s 8ms/step - loss: 8.7811e-04 - mean_squared_error: 8.7811e-04 - val_loss: 4.8154e-04 - val_mean_squared_error: 4.8154e-04
# Epoch 196/200
# 233/233 [==============================] - 2s 8ms/step - loss: 8.8022e-04 - mean_squared_error: 8.8022e-04 - val_loss: 4.7886e-04 - val_mean_squared_error: 4.7886e-04
# Epoch 197/200
# 233/233 [==============================] - 2s 8ms/step - loss: 8.7884e-04 - mean_squared_error: 8.7884e-04 - val_loss: 4.8079e-04 - val_mean_squared_error: 4.8079e-04
# Epoch 198/200
# 233/233 [==============================] - 2s 8ms/step - loss: 8.7693e-04 - mean_squared_error: 8.7693e-04 - val_loss: 4.8139e-04 - val_mean_squared_error: 4.8139e-04
# Epoch 199/200
# 233/233 [==============================] - 2s 8ms/step - loss: 8.7994e-04 - mean_squared_error: 8.7994e-04 - val_loss: 4.7860e-04 - val_mean_squared_error: 4.7860e-04
# Epoch 200/200
# 233/233 [==============================] - 2s 8ms/step - loss: 8.8030e-04 - mean_squared_error: 8.8030e-04 - val_loss: 4.8904e-04 - val_mean_squared_error: 4.8904e-04

# %% [markdown]
# Finally, Training is done.

# %% [markdown]
# # Predict image from model

# %% [markdown]
# ## 초해상화 2x

# %%
fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(Image.open('./Test/Set5/butterfly_GT.bmp'))
ax.title.set_text("Original Image")
plt.show()

# %% [markdown]
# Then we need to make distorted image by resizing down and up.

# %%
# Make output directory
try:
    os.listdir('./output')
except:
    os.mkdir('./output')

target = cv2.imread('./Test/Set5/butterfly_GT.bmp', cv2.IMREAD_COLOR)
target = cv2.cvtColor(target, cv2.COLOR_BGR2YCrCb)
shape = target.shape

# Resize down by scale of 2
Y_img = cv2.resize(target[:, :, 0], (int(shape[1] / 2), int(shape[0] / 2)), cv2.INTER_CUBIC)

# Resize up to orignal image
Y_img = cv2.resize(Y_img, (shape[1], shape[0]), cv2.INTER_CUBIC)
target[:, :, 0] = Y_img
target = cv2.cvtColor(target, cv2.COLOR_YCrCb2BGR)
cv2.imwrite('./output/butterfly_bicubic_scale_2.jpg', target)

fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(Image.open('./output/butterfly_bicubic_scale_2.jpg'))
ax.title.set_text("Distorted Image")
plt.show()

# %%
Y = np.zeros((1, target.shape[0], target.shape[1], 1), dtype=np.float32)
# Normalize
Y[0, :, :, 0] = Y_img.astype(np.float32) / 255.

# Predict
pre = srcnn_model.predict(Y, batch_size=1) * 255.

# Post process output
pre[pre[:] > 255] = 255
pre[pre[:] < 0] = 0
pre = pre.astype(np.uint8)

# Copy y channel back to image and convert to BGR
output = cv2.cvtColor(target, cv2.COLOR_BGR2YCrCb)
output[6: -6, 6: -6, 0] = pre[0, :, :, 0]
output = cv2.cvtColor(output, cv2.COLOR_YCrCb2BGR)

# Save image
cv2.imwrite('./output/butterfly_Predicted_scale_2.jpg', output)

fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(Image.open('./output/butterfly_Predicted_scale_2.jpg'))
ax.title.set_text("Predicted Image")
plt.show()
# Out:
# 1/1 [==============================] - 0s 356ms/step

# %% [markdown]
# We can compare those images simultaneously.

# %%
original = ('./Test/Set5/butterfly_GT.bmp')
distorted = ('./output/butterfly_bicubic_scale_2.jpg')
predicted = ('./output/butterfly_Predicted_scale_2.jpg')

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 10))
ax[0].imshow(Image.open(original))
ax[0].title.set_text("Original Image")

ax[1].imshow(Image.open(distorted))
ax[1].title.set_text("Distorted Image")

ax[2].imshow(Image.open(predicted))
ax[2].title.set_text("Predicted Image")

# %%
def crop(image, left_top, x=200, y=200):
  return image[left_top[0]:(left_top[0]+x), left_top[1]:(left_top[1]+y), :]

# %%
# 자세히 시각화하기 위해 3개 영역 잘라내기
# 아래는 잘라낸 부분의 좌상단 좌표 3개
left_tops = [(400,500), (300,1200), (0,1000)]

images = []
for left_top in left_tops:
  img1 = crop(original, left_top, 200, 200)
  img2 = crop(distorted, left_top, 200, 200)
  img3 = crop(predicted, left_top, 200, 200)
  images.extend([img1, img2, img3])
        
labels = ["original", "distorted", "predicted"] * 3 

plt.figure(figsize=(18,18))
for i in range(9):
  plt.subplot(3,3,i+1)
  plt.imshow(images[i])
  plt.title(labels[i], fontsize=30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-67d41a79bb57> in <module>
#       5 images = []
#       6 for left_top in left_tops:
# ----> 7   img1 = crop(original, left_top, 200, 200)
#       8   img2 = crop(distorted, left_top, 200, 200)
#       9   img3 = crop(predicted, left_top, 200, 200)
#
# <ipython-input-50-762e1fbd387e> in crop(image, left_top, x, y)
#       1 def crop(image, left_top, x=200, y=200):
# ----> 2   return image[left_top[0]:(left_top[0]+x), left_top[1]:(left_top[1]+y), :]
#
# TypeError: string indices must be integers

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 10))
ax[0].imshow(Image.open('./output/butterfly_bicubic_scale_2.jpg'))
ax[0].title.set_text("Distorted Image")

ax[1].imshow(Image.open('./output/butterfly_Predicted_scale_2.jpg'))
ax[1].title.set_text("Predicted Image")

# %% [markdown]
# Here, we can use PSNR and SSIM metrics for comparison. Of course, we need to compare each images with original image.

# %%
original = cv2.imread('./Test/Set5/butterfly_GT.bmp')
distorted = cv2.imread('./output/butterfly_bicubic_scale_2.jpg')
predicted = cv2.imread('./output/butterfly_Predicted_scale_2.jpg')

# %% [markdown]
# #### 원본과 왜곡(2x) 이미지 비교 (평가식)

# %%
metrics = compare_images(original, distorted)
print("Metrics for original and distorted image")
print("PSNR: {}".format(metrics[0]))
print("MSE: {}".format(metrics[1]))
print("SSIM: {}".format(metrics[2]))
# Out:
# Metrics for original and distorted image
# PSNR: 24.72398539185269
# MSE: 657.3596801757812
# SSIM: 0.8718794090483074
# <ipython-input-7-dffab844877c>:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   err /= np.float(target_data.shape[0] * target_data.shape[1])

# %% [markdown]
# #### 원본과 초해상화(2x) 이미지 비교 (평가식)

# %%
metrics = compare_images(original, predicted)
print("Metrics for original and predicted image")
print("PSNR: {}".format(metrics[0]))
print("MSE: {}".format(metrics[1]))
print("SSIM: {}".format(metrics[2]))
# Out:
# Metrics for original and predicted image
# PSNR: 28.829607337774476
# MSE: 255.41175842285156
# SSIM: 0.9357735520912825
# <ipython-input-7-dffab844877c>:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   err /= np.float(target_data.shape[0] * target_data.shape[1])
